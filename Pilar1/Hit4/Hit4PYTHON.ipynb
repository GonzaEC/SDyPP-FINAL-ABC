# %%
import hashlib
resultado = hashlib.md5("hola mundo".encode()).hexdigest()
print(f"Input:  hola mundo")
print(f"MD5:    {resultado}")
# Out:
# Input:  hola mundo
# MD5:    0ad066a5d29f3f2a2a1c7c17dd082a79
